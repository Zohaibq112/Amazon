# %%
a=(input("enter number"))
b=a[::-1]
if a==b:
    print("number is palindrome")
else:
    print("number is not")
# Out:
# enter number 121
# number is palindrome

# %%
b.append(thislist)
print(b)
# Out:
# ['wassay', ['Niggesh'], ['Niggesh']]

# %%
thislist.insert("Wasay")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 thislist.insert("Wasay")
#
# TypeError: insert expected 2 arguments, got 1

# %%
b = [1,2,3]
b.push(1)
print(b)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 b = [1,2,3]
# ----> 2 b.push(1)
#       3 print(b)
#
# AttributeError: 'list' object has no attribute 'push'

# %%
adict = {"name" : "Wasay"}
print(adict.items())
# Out:
# dict_items([('name', 'Wasay')])
